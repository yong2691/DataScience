# %%
import pandas as pd

alco2009 = pd.read_csv("/content/niaaa-report2009.csv", index_col=("State","Beer","Wine","Spirits"))
alco2009.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Alabama, 1.2, 0.22, 0.58), (Alaska, 1.31, 0.54, 1.16), (Arizona, 1.19, 0.38, 0.74), (Arkansas, 1.07, 0.17, 0.6), (California, 1.05, 0.55, 0.73)]

# %%
alco2009.shape
# Out:
# (51, 0)

# %%
alco2009.size
# Out:
# 0

# %%
alco2009.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 51 entries, ('Alabama', 1.2, 0.22, 0.58) to ('Wyoming', 1.45, 0.22, 1.1)
# Empty DataFrame

# %%
import pandas as pd

alco2009 = pd.read_csv("/content/niaaa-report2009.csv", index_col="State")
alco2009.head()
# Out:
#             Beer  Wine  Spirits
# State
# Alabama     1.20  0.22     0.58
# Alaska      1.31  0.54     1.16
# Arizona     1.19  0.38     0.74
# Arkansas    1.07  0.17     0.60
# California  1.05  0.55     0.73

# %%
alco2009.size
# Out:
# 153

# %%
alco2009.shape
# Out:
# (51, 3)

# %%
alco2009.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Wyoming
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Beer     51 non-null     float64
#  1   Wine     51 non-null     float64
#  2   Spirits  51 non-null     float64
# dtypes: float64(3)
# memory usage: 1.6+ KB

# %%
alco2009["Wine"].head()
# Out:
# State
# Alabama       0.22
# Alaska        0.54
# Arizona       0.38
# Arkansas      0.17
# California    0.55
# Name: Wine, dtype: float64

# %%
alco2009.Wine.head() #위에랑 같다.
# Out:
# State
# Alabama       0.22
# Alaska        0.54
# Arizona       0.38
# Arkansas      0.17
# California    0.55
# Name: Wine, dtype: float64

# %%
# 새로운 열 추가
alco2009["Total"] = 0
alco2009.head()
# Out:
#             Beer  Wine  Spirits  Total
# State
# Alabama     1.20  0.22     0.58      0
# Alaska      1.31  0.54     1.16      0
# Arizona     1.19  0.38     0.74      0
# Arkansas    1.07  0.17     0.60      0
# California  1.05  0.55     0.73      0

# %%
# 새로운 열 추가
alco2009["추가"] = 0
alco2009.head()
# Out:
#             Beer  Wine  Spirits  Total  추가
# State
# Alabama     1.20  0.22     0.58      0   0
# Alaska      1.31  0.54     1.16      0   0
# Arizona     1.19  0.38     0.74      0   0
# Arkansas    1.07  0.17     0.60      0   0
# California  1.05  0.55     0.73      0   0

# %%
#인덱스 변경하기
alco2009.reset_index().set_index("Beer").head() #일단 리셋시키고 인덱스 세팅. 임시로만 바뀐것이다. 원데이터에서는 안바뀌고 State가 인덱스로 되어 있다.
# Out:
#            State  Wine  Spirits  Total  추가
# Beer
# 1.20     Alabama  0.22     0.58      0   0
# 1.31      Alaska  0.54     1.16      0   0
# 1.19     Arizona  0.38     0.74      0   0
# 1.07    Arkansas  0.17     0.60      0   0
# 1.05  California  0.55     0.73      0   0

# %%
alco2009.loc["Nebraska"]
# Out:
# Beer       1.46
# Wine       0.20
# Spirits    0.68
# Total      0.00
# 추가         0.00
# Name: Nebraska, dtype: float64

# %%
# in 연산자 데이터 프레임의 특정 레이블을 가진 행이 있는지 확인
"Samoa" in alco2009.index
# Out:
# False

# %%
"Nebraska" in alco2009.index
# Out:
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-85fd8863f313> in <module>()
# ----> 1 pd.groupby("State")["Alaska"]
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'groupby'
